# %%
import psutil, time, pandas as pd, matplotlib.pyplot as plt, numpy as np
print("✅ Environment ready!")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import psutil, time, pandas as pd, matplotlib.pyplot as plt, numpy as np
#       2 print("✅ Environment ready!")
#
# ModuleNotFoundError: No module named 'pandas'
